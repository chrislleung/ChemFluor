# %% [markdown]
# # Train Models on Compute Canada
#
# This notebook submits the training job to Slurm. Full training should not be run directly inside the notebook or on the login node.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.insert(0, str(PROJECT_ROOT))
print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Submit the Slurm Job
#
# Run the next cell on Nibi. It submits `run_chemfluor.sh`, which runs `python -u -m src.train` on a compute node.

# %%
# !sbatch ../run_chemfluor.sh

# %% [markdown]
# ## Check Job Status

# %%
# !squeue -u $USER

# %% [markdown]
# ## Find Recent Output Logs

# %%
# !ls -lt ../outputs/*.out 2>/dev/null | head

# %% [markdown]
# ## Inspect a Specific Job Log
#
# Replace `JOBID` below with the actual job number printed by `sbatch`.

# %%
JOBID = "REPLACE_WITH_JOB_ID"
# !tail -n 120 ../outputs/chemfluor_{JOBID}.out

# %% [markdown]
# ## After Training Finishes
#
# Open `03_view_results.ipynb` to inspect metrics and plots.
