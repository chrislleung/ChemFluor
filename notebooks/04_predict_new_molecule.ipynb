# %% [markdown]
# # Predict a New Molecule
#
# Use this notebook to enter one candidate molecule and solvent. The model will return predicted emission wavelength, PLQY, bright/dim classification, and an applicability-domain confidence warning.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.insert(0, str(PROJECT_ROOT))
print("Project root:", PROJECT_ROOT)

# %% [markdown]
# ## Enter Candidate Information
#
# Edit the values in the next cell.

# %%
SMILES = "c1ccccc1"
SOLVENT = "MeCN"
NAME = "candidate_1"

# %% [markdown]
# ## Run Prediction
#
# This command uses the trained models and metadata saved in `outputs/models/`. If the command reports missing files, run training first.

# %%
# !python -m src.predict --smiles "{SMILES}" --solvent "{SOLVENT}" --name "{NAME}"

# %% [markdown]
# ## Save Prediction as JSON

# %%
output_path = PROJECT_ROOT / "outputs" / "predictions" / f"{NAME}_prediction.json"
# !python -m src.predict --smiles "{SMILES}" --solvent "{SOLVENT}" --name "{NAME}" --output "{output_path}"
print("Saved to:", output_path)

# %% [markdown]
# ## Interpretation
#
# - **High confidence**: similar molecule/scaffold and solvent are represented in training.
# - **Medium confidence**: moderate similarity or new scaffold but still some support.
# - **Low confidence**: unfamiliar structure, unknown solvent, missing descriptors, or high uncertainty.
#
# Low-confidence predictions should be treated as rough screening estimates.
